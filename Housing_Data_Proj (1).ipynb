# %%
import kagglehub
path = kagglehub.dataset_download("amitabhajoy/bengaluru-house-price-data")
# Out:
# Using Colab cache for faster access to the 'bengaluru-house-price-data' dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(path)
# Out:
# /kaggle/input/bengaluru-house-price-data

# %%
import os

# List the contents of the downloaded directory to find the CSV file
directory_contents = os.listdir(path)
print(f"Contents of the downloaded directory: {directory_contents}")

# Assuming there's one CSV file, find it
csv_file = [f for f in directory_contents if f.endswith('.csv')]

if csv_file:
    # Construct the full path to the CSV file
    csv_file_path = os.path.join(path, csv_file[0])
    print(f"Reading CSV file from: {csv_file_path}")
    df = pd.read_csv(csv_file_path)
    print('Successfully Loaded')
else:
    print("No CSV file found in the downloaded directory.")
# Out:
# Contents of the downloaded directory: ['Bengaluru_House_Data.csv']
# Reading CSV file from: /kaggle/input/bengaluru-house-price-data/Bengaluru_House_Data.csv
# Successfully Loaded

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
columns = df[['area_type', 'availability', 'location', 'size', 'society']]

# %%
columns
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society
# 0          2 BHK  Coomee
# 1      4 Bedroom  Theanmp
# 2          3 BHK      NaN
# 3          3 BHK  Soiewre
# ...

# %%
for i in columns:
    print(df[i].unique())
    print("-"*60)
# Out:
# ['Super built-up  Area' 'Plot  Area' 'Built-up  Area' 'Carpet  Area']
# ------------------------------------------------------------
# ['19-Dec' 'Ready To Move' '18-May' '18-Feb' '18-Nov' '20-Dec' '17-Oct'
#  '21-Dec' '19-Sep' '20-Sep' '18-Mar' '20-Feb' '18-Apr' '20-Aug' '18-Oct'
#  '19-Mar' '17-Sep' '18-Dec' '17-Aug' '19-Apr' '18-Jun' '22-Dec' '22-Jan'
#  '18-Aug' '19-Jan' '17-Jul' '18-Jul' '21-Jun' '20-May' '19-Aug' '18-Sep'
#  '17-May' '17-Jun' '21-May' '18-Jan' '20-Mar' '17-Dec' '16-Mar' '19-Jun'
#  '22-Jun' '19-Jul' '21-Feb' 'Immediate Possession' '19-May' '17-Nov'
#  '20-Oct' '20-Jun' '19-Feb' '21-Oct' '21-Jan' '17-Mar' '17-Apr' '22-May'
#  '19-Oct' '21-Jul' '21-Nov' '21-Mar' '16-Dec' '22-Mar' '20-Jan' '21-Sep'
#  '21-Aug' '14-Nov' '19-Nov' '15-Nov' '16-Jul' '15-Jun' '17-Feb' '20-Nov'
#  '20-Jul' '16-Sep' '15-Oct' '15-Dec' '16-Oct' '22-Nov' '15-Aug' '17-Jan'
#  '16-Nov' '20-Apr' '16-Jan' '14-Jul']
# ------------------------------------------------------------
# ...

# %%
for column in df.columns:
  print(df[column].value_counts())
  print("-"*20)
# Out:
# area_type
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: count, dtype: int64
# --------------------
# availability
# Ready To Move    10581
# 18-Dec             307
# 18-May             295
# 18-Apr             271
# 18-Aug             200
#                  ...
# 16-Oct               1
# 17-Jan               1
# 16-Nov               1
# 16-Jan               1
# 14-Jul               1
# Name: count, Length: 81, dtype: int64
# --------------------
# location
# Whitefield                         540
# Sarjapur  Road                     399
# Electronic City                    302
# Kanakpura Road                     273
# Thanisandra                        234
#                                   ...
# 3rd Stage Raja Rajeshwari Nagar      1
# Chuchangatta Colony                  1
# Electronic City Phase 1,             1
# Chikbasavanapura                     1
# Abshot Layout                        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df['location'].fillna('Whitefield',inplace=True)
# Out:
# /tmp/ipykernel_754/2056135260.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['location'].fillna('Whitefield',inplace=True)

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df['size'].replace(r"(?i)(\d+)\s*(Bedroom(s)?|BHK)", r"\1BHK",regex=True,inplace=True)
# Out:
# /tmp/ipykernel_754/1431742691.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['size'].replace(r"(?i)(\d+)\s*(Bedroom(s)?|BHK)", r"\1BHK",regex=True,inplace=True)

# %%
df.head()
# Out:
#               area_type   availability                  location  size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II  2BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4BHK
# 2        Built-up  Area  Ready To Move               Uttarahalli  3BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli  3BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur  2BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df['size'].isnull().value_counts()
# Out:
# size
# False    13304
# True        16
# Name: count, dtype: int64

# %%
df['size'].fillna('2BHK',inplace=True)
# Out:
# /tmp/ipykernel_754/852650198.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['size'].fillna('2BHK',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13320 non-null  object
#  3   size          13320 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df['bath'].describe()
# Out:
# count    13247.000000
# mean         2.692610
# std          1.341458
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          3.000000
# max         40.000000
# Name: bath, dtype: float64

# %%
df['bath'].fillna(2,inplace=True)
# Out:
# /tmp/ipykernel_754/2315161015.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bath'].fillna(2,inplace=True)

# %%
df['balcony'].describe()
# Out:
# count    12711.000000
# mean         1.584376
# std          0.817263
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          3.000000
# Name: balcony, dtype: float64

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 2.0    5113
# 1.0    4897
# 3.0    1672
# 0.0    1029
# Name: count, dtype: int64

# %%
df['balcony'].ffill(inplace=True)
# Out:
# /tmp/ipykernel_754/2286980021.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['balcony'].ffill(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13320 non-null  object
#  3   size          13320 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13320 non-null  float64
#  7   balcony       13320 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.drop(columns={'society'},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13320 non-null  object
#  3   size          13320 non-null  object
#  4   total_sqft    13320 non-null  object
#  5   bath          13320 non-null  float64
#  6   balcony       13320 non-null  float64
#  7   price         13320 non-null  float64
# dtypes: float64(3), object(5)
# memory usage: 832.6+ KB

# %%
df.head()
# Out:
#               area_type   availability                  location  size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II  2BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4BHK
# 2        Built-up  Area  Ready To Move               Uttarahalli  3BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli  3BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur  2BHK
#
#   total_sqft  bath  balcony   price
# 0       1056   2.0      1.0   39.07
# 1       2600   5.0      3.0  120.00
# 2       1440   2.0      3.0   62.00
# 3       1521   3.0      1.0   95.00
# 4       1200   2.0      1.0   51.00

# %%
df['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def clean_sqt(x):
  token=str(x).split("-")
  if len(token)==2:
    return (float(token[0])+ float(token[1]))/2
  try:
    return float(x)
  except:
    return None

# %%
df['total_sqft'] = df['total_sqft'].apply(clean_sqt)

# %%
df['total_sqft'].unique()
# Out:
# array([1056. , 2600. , 1440. , ..., 1258.5,  774. , 4689. ])

# %%
df
# Out:
#                   area_type   availability                  location  size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II  2BHK
# 1                Plot  Area  Ready To Move          Chikka Tirupathi  4BHK
# 2            Built-up  Area  Ready To Move               Uttarahalli  3BHK
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli  3BHK
# 4      Super built-up  Area  Ready To Move                  Kothanur  2BHK
# ...                     ...            ...                       ...   ...
# 13315        Built-up  Area  Ready To Move                Whitefield  5BHK
# 13316  Super built-up  Area  Ready To Move             Richards Town  4BHK
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  2BHK
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar  4BHK
# 13319  Super built-up  Area  Ready To Move              Doddathoguru  1BHK
#
#        total_sqft  bath  balcony   price
# ...

# %%
dummy = df['size']

# %%
df['BHK'] = dummy.str.extract('(\d+)').astype(int)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_754/834038612.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['BHK'] = dummy.str.extract('(\d+)').astype(int)

# %%
df
# Out:
#                   area_type   availability                  location  size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II  2BHK
# 1                Plot  Area  Ready To Move          Chikka Tirupathi  4BHK
# 2            Built-up  Area  Ready To Move               Uttarahalli  3BHK
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli  3BHK
# 4      Super built-up  Area  Ready To Move                  Kothanur  2BHK
# ...                     ...            ...                       ...   ...
# 13315        Built-up  Area  Ready To Move                Whitefield  5BHK
# 13316  Super built-up  Area  Ready To Move             Richards Town  4BHK
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  2BHK
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar  4BHK
# 13319  Super built-up  Area  Ready To Move              Doddathoguru  1BHK
#
#        total_sqft  bath  balcony   price  BHK
# ...

# %%
df.drop(columns=["area_type","availability", "size"],inplace=True)

# %%
df.describe()
# Out:
#          total_sqft          bath       balcony         price           BHK
# count  13274.000000  13320.000000  13320.000000  13320.000000  13320.000000
# mean    1559.626694      2.688814      1.586411    112.565627      2.802778
# std     1238.405258      1.338754      0.818939    148.971674      1.294496
# min        1.000000      1.000000      0.000000      8.000000      1.000000
# 25%     1100.000000      2.000000      1.000000     50.000000      2.000000
# 50%     1276.000000      2.000000      2.000000     72.000000      3.000000
# 75%     1680.000000      3.000000      2.000000    120.000000      3.000000
# max    52272.000000     40.000000      3.000000   3600.000000     43.000000

# %%
df
# Out:
#                        location  total_sqft  bath  balcony   price  BHK
# 0      Electronic City Phase II      1056.0   2.0      1.0   39.07    2
# 1              Chikka Tirupathi      2600.0   5.0      3.0  120.00    4
# 2                   Uttarahalli      1440.0   2.0      3.0   62.00    3
# 3            Lingadheeranahalli      1521.0   3.0      1.0   95.00    3
# 4                      Kothanur      1200.0   2.0      1.0   51.00    2
# ...                         ...         ...   ...      ...     ...  ...
# 13315                Whitefield      3453.0   4.0      0.0  231.00    5
# 13316             Richards Town      3600.0   5.0      0.0  400.00    4
# 13317     Raja Rajeshwari Nagar      1141.0   2.0      1.0   60.00    2
# 13318           Padmanabhanagar      4689.0   4.0      1.0  488.00    4
# 13319              Doddathoguru       550.0   1.0      1.0   17.00    1
#
# [13320 rows x 6 columns]

# %% [markdown]
# Calculating Price per sqft

# %%
df['price_per_sqft'] = df['total_sqft'] * 100000 / df['price']

# %%
df
# Out:
#                        location  total_sqft  bath  balcony   price  BHK  \
# 0      Electronic City Phase II      1056.0   2.0      1.0   39.07    2
# 1              Chikka Tirupathi      2600.0   5.0      3.0  120.00    4
# 2                   Uttarahalli      1440.0   2.0      3.0   62.00    3
# 3            Lingadheeranahalli      1521.0   3.0      1.0   95.00    3
# 4                      Kothanur      1200.0   2.0      1.0   51.00    2
# ...                         ...         ...   ...      ...     ...  ...
# 13315                Whitefield      3453.0   4.0      0.0  231.00    5
# 13316             Richards Town      3600.0   5.0      0.0  400.00    4
# 13317     Raja Rajeshwari Nagar      1141.0   2.0      1.0   60.00    2
# 13318           Padmanabhanagar      4689.0   4.0      1.0  488.00    4
# 13319              Doddathoguru       550.0   1.0      1.0   17.00    1
#
#        price_per_sqft
# 0        2.702841e+06
# 1        2.166667e+06
# 2        2.322581e+06
# ...

# %%
df['location'].value_counts()
# Out:
# location
# Whitefield                         541
# Sarjapur  Road                     399
# Electronic City                    302
# Kanakpura Road                     273
# Thanisandra                        234
#                                   ...
# 3rd Stage Raja Rajeshwari Nagar      1
# Chuchangatta Colony                  1
# Electronic City Phase 1,             1
# Chikbasavanapura                     1
# Abshot Layout                        1
# Name: count, Length: 1305, dtype: int64

# %%
df['location'] = df['location'].apply(lambda x:x.strip())
location_count = df['location'].value_counts()

# %%
location_count_less_10 = location_count[location_count<=10]
location_count_less_10
# Out:
# location
# Basapura                                10
# Dairy Circle                            10
# Nagappa Reddy Layout                    10
# Naganathapura                           10
# Sector 1 HSR Layout                     10
#                                         ..
# Duddanahalli                             1
# Doddanakunte                             1
# Jogupalya                                1
# Subhash Nagar                            1
# Kengeri Satellite Town KHB Apartment     1
# Name: count, Length: 1053, dtype: int64

# %%
df['location'] = df['location'].apply(lambda x : 'other' if x in location_count_less_10 else x)

# %%
df['location'].value_counts()
# Out:
# location
# other                        2885
# Whitefield                    542
# Sarjapur  Road                399
# Electronic City               304
# Kanakpura Road                273
#                              ...
# Tindlu                         11
# Marsur                         11
# 2nd Phase Judicial Layout      11
# Thyagaraja Nagar               11
# HAL 2nd Stage                  11
# Name: count, Length: 242, dtype: int64
